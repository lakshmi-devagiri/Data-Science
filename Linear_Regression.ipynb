# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakki30/Linear_Regression/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-552b4def-21b4-4fae-8636-983f2cf0ffee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-552b4def-21b4-4fae-8636-983f2cf0ffee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Book1.xlsx')

# %%
df
# Out:
#    area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sqrft)')
plt.ylabel('Price(USD)')
plt.scatter(df.area, df.Price, color='Black', marker='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.Price)
# Out:
# LinearRegression()

# %%
#prediction
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.predict([[5300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([900291.09589041])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9beb5125-df33-4875-ad62-0f5d4e4350b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9beb5125-df33-4875-ad62-0f5d4e4350b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_excel('Book2.xlsx')

# %%
df1
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100
# 13  3900

# %%
p = reg.predict(df1)

# %%
df1['Price'] = p

# %%
df1
# Out:
#     area         Price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06
# 13  3900  7.101884e+05

# %%
df1.to_excel('Book2.xlsx',index='False')

# %%
# %matplotlib inline
plt.xlabel('area(sqrft)')
plt.ylabel('Price(USD)')
plt.scatter(df.area, df.Price, color='Black', marker='*')
plt.plot(df.area, reg.predict(df[['area']]), color='red')

# %%
df1
# Out:
#     area         Price
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06
# 13  3900  7.101884e+05

# %%
df1['Price'] = df1['Price'].astype(float)

# %%
df1
# Out:
#     area         Price         price
# 0   1000  3.164041e+05  3.164041e+05
# 1   1500  3.842979e+05  3.842979e+05
# 2   2300  4.929281e+05  4.929281e+05
# 3   3540  6.613048e+05  6.613048e+05
# 4   4120  7.400616e+05  7.400616e+05
# 5   4560  7.998082e+05  7.998082e+05
# 6   5490  9.260908e+05  9.260908e+05
# 7   3460  6.504418e+05  6.504418e+05
# 8   4750  8.256079e+05  8.256079e+05
# 9   2300  4.929281e+05  4.929281e+05
# 10  9000  1.402705e+06  1.402705e+06
# 11  8600  1.348390e+06  1.348390e+06
# 12  7100  1.144709e+06  1.144709e+06
# 13  3900  7.101884e+05  7.101884e+05
